# %%
print ("hello, world!")
# Out:
# hello, world!

# %%
import numpy as np
import pandas as pd

# %%
# code review

# movies with more than 7 rating & greater than 50M gross

# df[(df['ratings']>50)&(movies['gross'] > 5000000)] → one can use 5e7 for ceros

# top 3 gross romance movies after 1999, not included (typecast it to date time)

#df.sort_values("gross", ascending=False).loc[(df['release_date'] >= '2000-01-01') & (df['genre'] == 'Romance') ].head(3)

# %% [markdown]
# ### Import of .csv file

# %%
#note that the file needs to be in the correct folder. Also, when full path is inserted type of "/" might change 

df = pd.read_csv("movies_2.csv")
df.head(3)
# Out:
#    MovieID               Title MPAA Rating      Budget        Gross  \
# 0        1  Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2  Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3      Turner & Hooch          PG  13000000.0   71079915.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
df.shape
# Out:
# (616, 11)

# %%
df.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df.isna().sum() # in older version is df.null, here isna helps identify NaN values across columns in DF
# Out:
# MovieID           0
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
df.isna().values.sum() #using values property to sum total NaN values across DF
# Out:
# 343

# %%
df.isna().sum().sum() #using values sum+sum achieves similar output as above
# Out:
# 343

# %%
df['Rating'].isna().sum() #NaN per column, in this case Rating is the example
# Out:
# 108

# %%
df_v1 = df.copy().drop(columns="Summary") # summary column not relevant here, so dropping

# %%
df_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 48.3+ KB

# %%
df_v1.dtypes # obtaining dtypes per column
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# dtype: object

# %%
#column rename in lowercase and units into a new DF  
df_v1a= df_v1.copy().rename(columns={'MovieID':'movieid','Title':'title','MPAA Rating':'mpaa_rating','Budget':'budget($)', 'Gross':'gross($)', 'Release Date':'release_date(yyyy.mm.dd)','Genre':'genre', 'Runtime':'runtime(min)', 'Rating':'rating(1-10)', 'Rating Count': 'rating_count(#)'})

# %%
df_v1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movieid                   616 non-null    int64
#  1   title                     615 non-null    object
#  2   mpaa_rating               615 non-null    object
#  3   budget($)                 615 non-null    float64
#  4   gross($)                  615 non-null    float64
#  5   release_date(yyyy.mm.dd)  615 non-null    object
#  6   genre                     615 non-null    object
#  7   runtime(min)              615 non-null    float64
#  8   rating(1-10)              508 non-null    float64
#  9   rating_count(#)           508 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 48.3+ KB

# %%
df_v1a.head(2)
# Out:
#    movieid               title mpaa_rating  budget($)     gross($)  \
# 0        1  Look Who's Talking       PG-13  7500000.0  296000000.0
# 1        2  Driving Miss Daisy          PG  7500000.0  145793296.0
#
#   release_date(yyyy.mm.dd)    genre  runtime(min)  rating(1-10)  \
# 0               1989-10-12  Romance          93.0           5.9
# 1               1989-12-13   Comedy          99.0           7.4
#
#    rating_count(#)
# 0          73638.0
# 1          91075.0

# %%
df_v1a['title'] = df_v1a['title'].str.lower() # lower method converts string into lowercase

# %%
df_v1a['mpaa_rating'] = df_v1a['mpaa_rating'].str.lower()

# %%
df_v1a['genre'] = df_v1a['genre'].str.lower()

# %%
df_v1a.head(2)
# Out:
#    movieid               title mpaa_rating  budget($)     gross($)  \
# 0        1  look who's talking       pg-13  7500000.0  296000000.0
# 1        2  driving miss daisy          pg  7500000.0  145793296.0
#
#   release_date(yyyy.mm.dd)    genre  runtime(min)  rating(1-10)  \
# 0               1989-10-12  romance          93.0           5.9
# 1               1989-12-13   comedy          99.0           7.4
#
#    rating_count(#)
# 0          73638.0
# 1          91075.0

# %%
df_v1a.tail(2)
# Out:
#      movieid              title mpaa_rating    budget($)      gross($)  \
# 614      615  avengers: endgame       pg-13  356000000.0  2.796000e+09
# 615        0                NaN         NaN          NaN           NaN
#
#     release_date(yyyy.mm.dd)   genre  runtime(min)  rating(1-10)  \
# 614               2019-04-22  action         181.0           NaN
# 615                      NaN     NaN           NaN           NaN
#
#      rating_count(#)
# 614              NaN
# 615              NaN

# %%
df_v1a.drop(615, inplace=True) # row with index 615 has been dropped given it was empty, note drop defaults to index, but can also be applied to columns

# %%
df_v1a.tail(2)
# Out:
#      movieid              title mpaa_rating    budget($)      gross($)  \
# 613      614      the lion king          pg  250000000.0  1.632000e+09
# 614      615  avengers: endgame       pg-13  356000000.0  2.796000e+09
#
#     release_date(yyyy.mm.dd)   genre  runtime(min)  rating(1-10)  \
# 613               2019-07-09   drama         118.0           NaN
# 614               2019-04-22  action         181.0           NaN
#
#      rating_count(#)
# 613              NaN
# 614              NaN

# %%
# df_v1a.loc[:, "gross($)"] = '$'+ df_v1a['gross($)'].map('{:,.0f}'.format)
# this will through out a obj and not respect the str format not being able to do future calcs

# %%
df_v1a.head()
# Out:
#    movieid                       title mpaa_rating   budget($)     gross($)  \
# 0        1          look who's talking       pg-13   7500000.0  296000000.0
# 1        2          driving miss daisy          pg   7500000.0  145793296.0
# 2        3              turner & hooch          pg  13000000.0   71079915.0
# 3        4  born on the fourth of july           r  14000000.0  161001698.0
# 4        5             field of dreams          pg  15000000.0   84431625.0
#
#   release_date(yyyy.mm.dd)    genre  runtime(min)  rating(1-10)  \
# 0               1989-10-12  romance          93.0           5.9
# 1               1989-12-13   comedy          99.0           7.4
# 2               1989-07-28    crime         100.0           7.2
# 3               1989-12-20      war         145.0           7.2
# 4               1989-04-21    drama         107.0           7.5
#
#    rating_count(#)
# 0          73638.0
# 1          91075.0
# 2          91415.0
# 3          91415.0
# 4         101702.0

# %%
df_v1a.tail()
# Out:
#      movieid                                  title mpaa_rating    budget($)  \
# 610      611         godzilla: king of the monsters       pg-13  200000000.0
# 611      612                            toy story 4           g  200000000.0
# 612      613  fast & furious presents: hobbs & shaw       pg-13  200000000.0
# 613      614                          the lion king          pg  250000000.0
# 614      615                      avengers: endgame       pg-13  356000000.0
#
#          gross($) release_date(yyyy.mm.dd)      genre  runtime(min)  \
# 610  3.859000e+08               2019-05-13  adventure         132.0
# 611  1.062000e+09               2019-06-11  animation         100.0
# 612  7.594000e+08               2019-07-13   thriller         136.0
# 613  1.632000e+09               2019-07-09      drama         118.0
# 614  2.796000e+09               2019-04-22     action         181.0
#
#      rating(1-10)  rating_count(#)
# 610           NaN              NaN
# ...

# %%
df_v1a['release_date(yyyy.mm.dd)'] = pd.to_datetime(df_v1a['release_date(yyyy.mm.dd)']) # setting the date column to dtype = "datetime" format

# %%
df_v1a.tail(2)
# Out:
#      movieid              title mpaa_rating    budget($)      gross($)  \
# 613      614      the lion king          pg  250000000.0  1.632000e+09
# 614      615  avengers: endgame       pg-13  356000000.0  2.796000e+09
#
#     release_date(yyyy.mm.dd)   genre  runtime(min)  rating(1-10)  \
# 613               2019-07-09   drama         118.0           NaN
# 614               2019-04-22  action         181.0           NaN
#
#      rating_count(#)
# 613              NaN
# 614              NaN

# %%
df_v1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movieid                   615 non-null    int64
#  1   title                     615 non-null    object
#  2   mpaa_rating               615 non-null    object
#  3   budget($)                 615 non-null    float64
#  4   gross($)                  615 non-null    float64
#  5   release_date(yyyy.mm.dd)  615 non-null    datetime64[ns]
#  6   genre                     615 non-null    object
#  7   runtime(min)              615 non-null    float64
#  8   rating(1-10)              508 non-null    float64
#  9   rating_count(#)           508 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 48.2+ KB

# %% [markdown]
# Generating random value to replace NaN values in rarting and rating count within 2 units of standard deviation

# %%
df_v1a["rating(1-10)"].std()
# Out:
# 0.8889276821945817

# %%
df_v1b = df_v1a.copy()

# %%
#defininf the ramge values to generate rate values
rat_up_range= df_v1b['rating(1-10)'].mean() + 2 * df_v1b['rating(1-10)'].std()
rat_low_range= df_v1b['rating(1-10)'].mean() - 2 * df_v1b['rating(1-10)'].std()
ratc_up_range= df_v1b['rating_count(#)'].mean() + 2 * df_v1b['rating_count(#)'].std()
ratc_low_range= df_v1b['rating_count(#)'].mean() - 2 * df_v1b['rating_count(#)'].std()

# %%
print(ratc_low_range)
print(ratc_up_range)
# Out:
# -303425.5518984103
# 981929.7920558907

# %%
# using the fillna() but random() can also be called (problem → how to randomize within the "mean-2*std" range)
df_v1b['rating(1-10)'] = df_v1b['rating(1-10)'].transform(lambda x: x.fillna(x.mean() - 2 * x.std()))

# %%
# using the fillna() but random() can also be called (problem → how to randomize within the "mean-2*std" range)
df_v1b['rating_count(#)'] = df_v1b['rating_count(#)'].transform(lambda x: x.fillna(x.mean() + 2 * x.std()))

# %%
df_v1b['rating(1-10)'] = df_v1b['rating(1-10)'].transform(lambda x: x.fillna(x.mean() - 2 * x.std()))

# %%
df_v1b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movieid                   615 non-null    int64
#  1   title                     615 non-null    object
#  2   mpaa_rating               615 non-null    object
#  3   budget($)                 615 non-null    float64
#  4   gross($)                  615 non-null    float64
#  5   release_date(yyyy.mm.dd)  615 non-null    datetime64[ns]
#  6   genre                     615 non-null    object
#  7   runtime(min)              615 non-null    float64
#  8   rating(1-10)              615 non-null    float64
#  9   rating_count(#)           615 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 48.2+ KB

# %%
df_v1b.tail(3)
# Out:
#      movieid                                  title mpaa_rating    budget($)  \
# 612      613  fast & furious presents: hobbs & shaw       pg-13  200000000.0
# 613      614                          the lion king          pg  250000000.0
# 614      615                      avengers: endgame       pg-13  356000000.0
#
#          gross($) release_date(yyyy.mm.dd)     genre  runtime(min)  \
# 612  7.594000e+08               2019-07-13  thriller         136.0
# 613  1.632000e+09               2019-07-09     drama         118.0
# 614  2.796000e+09               2019-04-22    action         181.0
#
#      rating(1-10)  rating_count(#)
# 612      5.139467    981929.792056
# 613      5.139467    981929.792056
# 614      5.139467    981929.792056

# %%
df_v1b.tail(3)
# Out:
#      movieid                                  title mpaa_rating    budget($)  \
# 612      613  fast & furious presents: hobbs & shaw       pg-13  200000000.0
# 613      614                          the lion king          pg  250000000.0
# 614      615                      avengers: endgame       pg-13  356000000.0
#
#          gross($) release_date(yyyy.mm.dd)     genre  runtime(min)  \
# 612  7.594000e+08               2019-07-13  thriller         136.0
# 613  1.632000e+09               2019-07-09     drama         118.0
# 614  2.796000e+09               2019-04-22    action         181.0
#
#      rating(1-10)  rating_count(#)
# 612      5.139467    981929.792056
# 613      5.139467    981929.792056
# 614      5.139467    981929.792056

# %%
# replace rating with median given skewed distribution

df_v1c = df_v1a.copy()
df_v1c["rating(1-10)"].fillna(value=df_v1c["rating(1-10)"].median(), inplace=True)
df_v1c["rating_count(#)"].fillna(value=df_v1c["rating_count(#)"].median(), inplace=True)

# %% [markdown]
# Continue with new DF with the randomized values filling in the missing/NaN values of previous DF

# %%
df_v1c.tail(3)
# Out:
#      movieid                                  title mpaa_rating    budget($)  \
# 612      613  fast & furious presents: hobbs & shaw       pg-13  200000000.0
# 613      614                          the lion king          pg  250000000.0
# 614      615                      avengers: endgame       pg-13  356000000.0
#
#          gross($) release_date(yyyy.mm.dd)     genre  runtime(min)  \
# 612  7.594000e+08               2019-07-13  thriller         136.0
# 613  1.632000e+09               2019-07-09     drama         118.0
# 614  2.796000e+09               2019-04-22    action         181.0
#
#      rating(1-10)  rating_count(#)
# 612           6.9         240347.5
# 613           6.9         240347.5
# 614           6.9         240347.5

# %%
#drop the duplicates (in "titles")


df_v1c =df_v1c.drop_duplicates(subset=['title'])

# %%
df_v1c.tail()
# Out:
#      movieid                                  title mpaa_rating    budget($)  \
# 608      609                         captain marvel       pg-13  175000000.0
# 610      611         godzilla: king of the monsters       pg-13  200000000.0
# 611      612                            toy story 4           g  200000000.0
# 612      613  fast & furious presents: hobbs & shaw       pg-13  200000000.0
# 614      615                      avengers: endgame       pg-13  356000000.0
#
#          gross($) release_date(yyyy.mm.dd)      genre  runtime(min)  \
# 608  1.128000e+09               2019-02-27     action         124.0
# 610  3.859000e+08               2019-05-13  adventure         132.0
# 611  1.062000e+09               2019-06-11  animation         100.0
# 612  7.594000e+08               2019-07-13   thriller         136.0
# 614  2.796000e+09               2019-04-22     action         181.0
#
#      rating(1-10)  rating_count(#)
# 608           6.9         240347.5
# ...

# %%
df_v1c['gross($)'].isnull().value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of gross($)
# False    609
# Name: count, dtype: int64>

# %%
#change float to int in specified columns (budget, gross)
df_v1c['gross($)'] = df_v1c['gross($)'].astype(int)
df_v1c['budget($)'] = df_v1c['budget($)'].astype(int)

# %% [markdown]
# Exercises/questions about data at hand

# %%
#show the movies with more than 7 in Rating & greater than 50 million Gross

df_v1c[df_v1c['rating(1-10)'] > 7][df_v1c['gross($)'] > 50000000]
# Out:
# C:\Users\EWF\AppData\Local\Temp\ipykernel_22548\1743192175.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_v1c[df_v1c['rating(1-10)'] > 7][df_v1c['gross($)'] > 50000000]
#      movieid                                title mpaa_rating  budget($)  \
# 1          2                   driving miss daisy          pg    7500000
# 2          3                       turner & hooch          pg   13000000
# 3          4           born on the fourth of july           r   14000000
# 4          5                      field of dreams          pg   15000000
# 6          7              when harry met sally...           r   16000000
# ..       ...                                  ...         ...        ...
# 505      506                           big hero 6          pg  165000000
# 506      507                         interstellar       pg-13  165000000
# 507      508  captain america: the winter soldier       pg-13  170000000
# ...

# %%
#show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating 

df_v1c[df_v1c['rating(1-10)'] > 7][df_v1c['gross($)'] >= 50000000][df_v1c['mpaa_rating'] == 'pg']
# Out:
# C:\Users\EWF\AppData\Local\Temp\ipykernel_22548\3087436257.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_v1c[df_v1c['rating(1-10)'] > 7][df_v1c['gross($)'] >= 50000000][df_v1c['mpaa_rating'] == 'pg']
# C:\Users\EWF\AppData\Local\Temp\ipykernel_22548\3087436257.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_v1c[df_v1c['rating(1-10)'] > 7][df_v1c['gross($)'] >= 50000000][df_v1c['mpaa_rating'] == 'pg']
#      movieid                                     title mpaa_rating  budget($)  \
# 1          2                        driving miss daisy          pg    7500000
# 2          3                            turner & hooch          pg   13000000
# 4          5                           field of dreams          pg   15000000
# 7          8                        dead poets society          pg   16400000
# 13        14                                    batman          pg   35000000
# ...

# %%
#count of Animation movies with more than 7 in Rating (use the shape() function)

df_v1c[df_v1c['genre'] == "animation"][df_v1c['rating(1-10)'] > 7].shape
# Out:
# C:\Users\EWF\AppData\Local\Temp\ipykernel_22548\2624881166.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_v1c[df_v1c['genre'] == "animation"][df_v1c['rating(1-10)'] > 7].shape
# (39, 10)

# %%
#show the list of top 5 movies based on Budget using n.largest()

df_v1c.nlargest(5, 'budget($)')
# Out:
#      movieid                                        title mpaa_rating  \
# 594      595                       avengers: infinity war       pg-13
# 454      455  pirates of the caribbean: on stranger tides       pg-13
# 614      615                            avengers: endgame       pg-13
# 574      575                     star wars: the last jedi       pg-13
# 375      376     pirates of the caribbean: at world's end       pg-13
#
#      budget($)    gross($) release_date(yyyy.mm.dd)            genre  \
# 594  400000000  2048000000               2018-04-23           action
# 454  380000000  1045713802               2011-05-14           action
# 614  356000000 -2147483648               2019-04-22           action
# 574  317000000  1333000000               2019-12-09  science fiction
# 375  300000000   961000000               2007-05-19        adventure
#
#      runtime(min)  rating(1-10)  rating_count(#)
# 594         149.0           6.9         240347.5
# ...

# %%
#show the list of top 5 movies based on Budget using sort_values()

df_v1c.sort_values("budget($)", ascending=False).head(5)
# Out:
#      movieid                                        title mpaa_rating  \
# 594      595                       avengers: infinity war       pg-13
# 454      455  pirates of the caribbean: on stranger tides       pg-13
# 614      615                            avengers: endgame       pg-13
# 574      575                     star wars: the last jedi       pg-13
# 375      376     pirates of the caribbean: at world's end       pg-13
#
#      budget($)    gross($) release_date(yyyy.mm.dd)            genre  \
# 594  400000000  2048000000               2018-04-23           action
# 454  380000000  1045713802               2011-05-14           action
# 614  356000000 -2147483648               2019-04-22           action
# 574  317000000  1333000000               2019-12-09  science fiction
# 375  300000000   961000000               2007-05-19        adventure
#
#      runtime(min)  rating(1-10)  rating_count(#)
# 594         149.0           6.9         240347.5
# ...

# %%
#show the top 5 Comedy movies by Rating

df_v1c[df_v1c['genre'] == 'comedy'].sort_values(by="rating(1-10)", ascending=False).head(6)
# Out:
#      movieid               title mpaa_rating  budget($)   gross($)  \
# 111      112        forrest gump       pg-13   55000000  677945399
# 185      186     the truman show          pg   60000000  264118201
# 254      255      monsters, inc.           g  115000000  562816256
# 80        81       groundhog day          pg   14600000   70906973
# 164      165  as good as it gets       pg-13   50000000  314178011
# 399      400        the hangover           r   35000000  459270619
#
#     release_date(yyyy.mm.dd)   genre  runtime(min)  rating(1-10)  \
# 111               1994-07-06  comedy         142.0           8.8
# 185               1998-06-04  comedy         103.0           8.1
# 254               2001-11-01  comedy          92.0           8.0
# 80                1993-02-11  comedy         101.0           8.0
# 164               1997-12-19  comedy         139.0           7.7
# 399               2009-06-05  comedy         100.0           7.7
#
#      rating_count(#)
# ...

# %%
# only return name of top 5 comedy movies 

top5_comedy = df_v1c[df_v1c['genre'] == 'comedy'].sort_values(by="rating(1-10)", ascending=False).head(5)

top5_comedy['title']
# Out:
# 111          forrest gump
# 185       the truman show
# 254        monsters, inc.
# 80          groundhog day
# 164    as good as it gets
# Name: title, dtype: object

# %%
#top 5 movie names by Rating

dftop5 = df_v1c.sort_values(by="rating(1-10)", ascending=False).head(5)
print(dftop5["title"])
# Out:
# 393                                  the dark knight
# 99                                      pulp fiction
# 83                                  schindler's list
# 287    the lord of the rings: the return of the king
# 98                                 jurassic park iii
# Name: title, dtype: object

# %%
df_v1c.head()
# Out:
#    movieid                       title mpaa_rating  budget($)   gross($)  \
# 0        1          look who's talking       pg-13    7500000  296000000
# 1        2          driving miss daisy          pg    7500000  145793296
# 2        3              turner & hooch          pg   13000000   71079915
# 3        4  born on the fourth of july           r   14000000  161001698
# 4        5             field of dreams          pg   15000000   84431625
#
#   release_date(yyyy.mm.dd)    genre  runtime(min)  rating(1-10)  \
# 0               1989-10-12  romance          93.0           5.9
# 1               1989-12-13   comedy          99.0           7.4
# 2               1989-07-28    crime         100.0           7.2
# 3               1989-12-20      war         145.0           7.2
# 4               1989-04-21    drama         107.0           7.5
#
#    rating_count(#)
# 0          73638.0
# 1          91075.0
# 2          91415.0
# 3          91415.0
# 4         101702.0

# %%
# top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)
top3_romance = df_v1c[(df_v1c['genre']== 'romance')]
top3_romance = top3_romance[top3_romance['release_date(yyyy.mm.dd)'] >= '2000-01-01']
top3_romance.nlargest(n=3, columns='gross($)')
# Out:
#      movieid                                      title mpaa_rating  \
# 464      465  the twilight saga: breaking dawn - part 2       pg-13
# 442      443  the twilight saga: breaking dawn - part 1       pg-13
# 401      402                the twilight saga: new moon       pg-13
#
#      budget($)   gross($) release_date(yyyy.mm.dd)    genre  runtime(min)  \
# 464  120000000  829000000               2012-11-13  romance         115.0
# 442  110000000  712171856               2011-03-15  romance         117.0
# 401   50000000  709827462               2009-03-15  romance         130.0
#
#      rating(1-10)  rating_count(#)
# 464           5.5         218357.0
# 442           4.9         211592.0
# 401           4.7         252223.0

# %%
#how many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)

df_v1c.value_counts(df_v1c['genre'])
# Out:
# genre
# action             109
# comedy              99
# animation           87
# drama               64
# thriller            40
# science fiction     37
# adventure           29
# family              29
# romance             28
# fantasy             26
# crime               17
# horror              14
# mystery             11
# war                  9
# western              6
# history              4
# Name: count, dtype: int64

# %%
# other way of having the count of genre 

print('there are', df_v1c["genre"].nunique(),'unique genres')
# Out:
# there are 16 unique genres

# %%
print('number of genres is:', len(pd.unique(df_v1c['genre'])))
# Out:
# number of genres is: 16

# %%
#top 5 expensive movies released after 1999, not included (measured by Budget)

top5_budget = df_v1c[df_v1c['release_date(yyyy.mm.dd)'] >= '2000-01-01']
top5_budget.nlargest(n=5, columns='budget($)')
# Out:
#      movieid                                        title mpaa_rating  \
# 594      595                       avengers: infinity war       pg-13
# 454      455  pirates of the caribbean: on stranger tides       pg-13
# 614      615                            avengers: endgame       pg-13
# 574      575                     star wars: the last jedi       pg-13
# 375      376     pirates of the caribbean: at world's end       pg-13
#
#      budget($)    gross($) release_date(yyyy.mm.dd)            genre  \
# 594  400000000  2048000000               2018-04-23           action
# 454  380000000  1045713802               2011-05-14           action
# 614  356000000 -2147483648               2019-04-22           action
# 574  317000000  1333000000               2019-12-09  science fiction
# 375  300000000   961000000               2007-05-19        adventure
#
#      runtime(min)  rating(1-10)  rating_count(#)
# 594         149.0           6.9         240347.5
# ...

# %%
#most & least frequent MPAA Rating in the dataset in terms of occurrences

df_v1c['genre'].value_counts()
# Out:
# genre
# action             109
# comedy              99
# animation           87
# drama               64
# thriller            40
# science fiction     37
# family              29
# adventure           29
# romance             28
# fantasy             26
# crime               17
# horror              14
# mystery             11
# war                  9
# western              6
# history              4
# Name: count, dtype: int64

# %%
# most and least expensive Genre (take an average of all Budget measures grouped by Genre - use groupBy() method)

expensive_genre= df_v1c.groupby('genre')['budget($)'].mean('budget($)')
print('the MOST expensive genre is', expensive_genre.nlargest(n=1, e))
print('the LEAST expensive genre is', expensive_genre.nsmallest(n=1))
# Out:
# the MOST expensive genre is genre
# fantasy    1.603731e+08
# Name: budget($), dtype: float64
# the LEAST expensive genre is genre
# horror    3.700429e+07
# Name: budget($), dtype: float64

# %%
#which Genre is favored the most by the people?

favored_genre = df_v1c.groupby('genre')['rating(1-10)'].mean('rating(1-10)') # grouping by genre and rating, while obtaining avg of rating
favored_genre.nlargest(n=1) #obtaining genre with highest avg rating
# Out:
# genre
# history    7.625
# Name: rating(1-10), dtype: float64

# %%
# favored genre weighting the rating and rating count

df_v1c['weighted_rating'] = df_v1c['rating(1-10)']*df_v1c['rating_count(#)']

genre_grouping = df_v1c.groupby('genre').agg(sum_weighted_rating = ('weighted_rating', 'sum'), sum_ratingcount= ('rating_count(#)', 'sum'))

genre_grouping['avg_weighted_rating'] = genre_grouping['sum_weighted_rating'] / genre_grouping['sum_ratingcount']

favored_genre = genre_grouping['avg_weighted_rating'].idxmax()

print('most favored genre is:', favored_genre)
# Out:
# most favored genre is: history
